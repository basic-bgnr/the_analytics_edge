# %%
#new tips
# //////////////////

from sklearn.externals.joblib import Memory
memory = Memory(location='/tmp', verbose=0)


@memory.cache
def fib(n):
    if n<=2:
        return 1
    return fib(n-1) + fib(n-2)

print(fib(1000))
# /////////////////
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /usr/lib/python3.5/inspect.py in getfullargspec(func)
#    1088                                        skip_bound_arg=False,
# -> 1089                                        sigcls=Signature)
#    1090     except Exception as ex:
#
# /usr/lib/python3.5/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2225         # of a Python function (Cython functions, for instance), then:
# -> 2226         return _signature_from_function(sigcls, obj)
#    2227
#
# /usr/lib/python3.5/inspect.py in _signature_from_function(cls, func)
#    2101         parameters.append(Parameter(name, annotation=annotation,
# -> 2102                                     kind=_POSITIONAL_OR_KEYWORD))
#    2103
#
# RecursionError: maximum recursion depth exceeded
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-e539b40c5c2f> in <module>
#      12     return fib(n-1) + fib(n-2)
#      13
# ---> 14 print(fib(1000))
#      15 # /////////////////
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ...
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     506
#     507         if must_call:
# --> 508             out, metadata = self.call(*args, **kwargs)
#     509             if self.mmap_mode is not None:
#     510                 # Memmap the output at the first call to be consistent with
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in call(self, *args, **kwargs)
#     706         if self._verbose > 0:
#     707             print(format_call(self.func, args, kwargs))
# --> 708         output = self.func(*args, **kwargs)
#     709         self.store_backend.dump_item(
#     710             [func_id, args_id], output, verbose=self._verbose)
#
# <ipython-input-22-e539b40c5c2f> in fib(n)
#      10     if n<=2:
#      11         return 1
# ---> 12     return fib(n-1) + fib(n-2)
#      13
#      14 print(fib(1000))
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in __call__(self, *args, **kwargs)
#     540
#     541     def __call__(self, *args, **kwargs):
# --> 542         return self._cached_call(args, kwargs)[0]
#     543
#     544     def __getstate__(self):
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _cached_call(self, args, kwargs, shelving)
#     455             Some metadata about wrapped function call (see _persist_input()).
#     456         """
# --> 457         func_id, args_id = self._get_output_identifiers(*args, **kwargs)
#     458         metadata = None
#     459         msg = None
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _get_output_identifiers(self, *args, **kwargs)
#     561         """Return the func identifier and input parameter hash of a result."""
#     562         func_id = _build_func_identifier(self.func)
# --> 563         argument_hash = self._get_argument_hash(*args, **kwargs)
#     564         return func_id, argument_hash
#     565
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/memory.py in _get_argument_hash(self, *args, **kwargs)
#     555
#     556     def _get_argument_hash(self, *args, **kwargs):
# --> 557         return hashing.hash(filter_args(self.func, self.ignore, args, kwargs),
#     558                             coerce_mmap=(self.mmap_mode is not None))
#     559
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/func_inspect.py in filter_args(func, ignore_lst, args, kwargs)
#     238                           'not work.' % func, stacklevel=2)
#     239         return {'*': args, '**': kwargs}
# --> 240     arg_spec = getfullargspec(func)
#     241     arg_names = arg_spec.args + arg_spec.kwonlyargs
#     242     arg_defaults = arg_spec.defaults or ()
#
# ~/.local/lib/python3.5/site-packages/sklearn/externals/joblib/func_inspect.py in getfullargspec(func)
#     172     """
#     173     try:
# --> 174         return inspect.getfullargspec(func)
#     175     except AttributeError:
#     176         arg_spec = inspect.getargspec(func)
#
# /usr/lib/python3.5/inspect.py in getfullargspec(func)
#    1093         # else. So to be fully backwards compatible, we catch all
#    1094         # possible exceptions here, and reraise a TypeError.
# -> 1095         raise TypeError('unsupported callable') from ex
#    1096
#    1097     args = []
#
# TypeError: unsupported callable
